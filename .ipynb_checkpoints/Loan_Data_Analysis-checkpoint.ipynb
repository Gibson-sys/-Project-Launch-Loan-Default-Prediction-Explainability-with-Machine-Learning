# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile

# %%
# extract 
ext_zip = zipfile.ZipFile("archive (2).zip")
ext_zip.extractall()

# %%
#load dataset
dataset = pd.read_csv("loan_data.csv")

# %%
dataset
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# 1                   0                   OWN     1000.0          EDUCATION
# 2                   3              MORTGAGE     5500.0            MEDICAL
# 3                   0                  RENT    35000.0            MEDICAL
# 4                   1                  RENT    35000.0            MEDICAL
# ...               ...                   ...        ...                ...
# 44995               6                  RENT    15000.0            MEDICAL
# 44996              17                  RENT     9000.0    HOMEIMPROVEMENT
# 44997               7                  RENT     2771.0  DEBTCONSOLIDATION
# 44998               4                  RENT    12000.0          EDUCATION
# 44999               1                  RENT     6665.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0              16.02                 0.49                         3.0
# 1              11.14                 0.08                         2.0
# 2              12.87                 0.44                         3.0
# 3              15.23                 0.44                         2.0
# 4              14.27                 0.53                         4.0
# ...              ...                  ...                         ...
# 44995          15.66                 0.31                         3.0
# 44996          14.07                 0.14                        11.0
# 44997          10.02                 0.05                        10.0
# 44998          13.23                 0.36                         6.0
# 44999          17.05                 0.13                         3.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 0               561                             No            1
# 1               504                            Yes            0
# 2               635                             No            1
# 3               675                             No            1
# 4               586                             No            1
# ...             ...                            ...          ...
# 44995           645                             No            1
# 44996           621                             No            1
# 44997           668                             No            1
# 44998           604                             No            1
# 44999           628                             No            1
#
# [45000 rows x 14 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
#  12  previous_loan_defaults_on_file  45000 non-null  object
#  13  loan_status                     45000 non-null  int64
# dtypes: float64(6), int64(3), object(5)
# memory usage: 4.8+ MB

# %%
dataset.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# 25%         8.590000             0.070000                    3.000000
# 50%        11.010000             0.120000                    4.000000
# 75%        12.990000             0.190000                    8.000000
# max        20.000000             0.660000                   30.000000
#
#        credit_score   loan_status
# count  45000.000000  45000.000000
# mean     632.608756      0.222222
# std       50.435865      0.415744
# min      390.000000      0.000000
# 25%      601.000000      0.000000
# 50%      640.000000      0.000000
# 75%      670.000000      0.000000
# max      850.000000      1.000000

# %%
dataset
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# 1                   0                   OWN     1000.0          EDUCATION
# 2                   3              MORTGAGE     5500.0            MEDICAL
# 3                   0                  RENT    35000.0            MEDICAL
# 4                   1                  RENT    35000.0            MEDICAL
# ...               ...                   ...        ...                ...
# 44995               6                  RENT    15000.0            MEDICAL
# 44996              17                  RENT     9000.0    HOMEIMPROVEMENT
# 44997               7                  RENT     2771.0  DEBTCONSOLIDATION
# 44998               4                  RENT    12000.0          EDUCATION
# 44999               1                  RENT     6665.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0              16.02                 0.49                         3.0
# 1              11.14                 0.08                         2.0
# 2              12.87                 0.44                         3.0
# 3              15.23                 0.44                         2.0
# 4              14.27                 0.53                         4.0
# ...              ...                  ...                         ...
# 44995          15.66                 0.31                         3.0
# 44996          14.07                 0.14                        11.0
# 44997          10.02                 0.05                        10.0
# 44998          13.23                 0.36                         6.0
# 44999          17.05                 0.13                         3.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 0               561                             No            1
# 1               504                            Yes            0
# 2               635                             No            1
# 3               675                             No            1
# 4               586                             No            1
# ...             ...                            ...          ...
# 44995           645                             No            1
# 44996           621                             No            1
# 44997           668                             No            1
# 44998           604                             No            1
# 44999           628                             No            1
#
# [45000 rows x 14 columns]

# %%
dataset["person_home_ownership"].unique()
# Out:
# array(['RENT', 'OWN', 'MORTGAGE', 'OTHER'], dtype=object)

# %%
dataset["person_home_ownership"].value_counts().plot(kind = "bar")
plt.show();

# %%
female_loan_data = dataset[dataset["person_gender"] == "female"]
female_loan_data["loan_status"].value_counts()
# Out:
# loan_status
# 0    15674
# 1     4485
# Name: count, dtype: int64

# %%
female_loan_data
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 5            21.0        female      High School        12951.0
# ...           ...           ...              ...            ...
# 44988        28.0        female        Associate        49170.0
# 44992        23.0        female         Bachelor        40925.0
# 44993        27.0        female      High School        35512.0
# 44994        24.0        female        Associate        31924.0
# 44996        37.0        female        Associate        65800.0
#
#        person_emp_exp person_home_ownership  loan_amnt      loan_intent  \
# 0                   0                  RENT    35000.0         PERSONAL
# 1                   0                   OWN     1000.0        EDUCATION
# 2                   3              MORTGAGE     5500.0          MEDICAL
# 3                   0                  RENT    35000.0          MEDICAL
# 5                   0                   OWN     2500.0          VENTURE
# ...               ...                   ...        ...              ...
# 44988               4                  RENT    10401.0  HOMEIMPROVEMENT
# 44992               0                  RENT     9000.0         PERSONAL
# 44993               4                  RENT     5000.0         PERSONAL
# 44994               2                  RENT    12229.0          MEDICAL
# 44996              17                  RENT     9000.0  HOMEIMPROVEMENT
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0              16.02                 0.49                         3.0
# 1              11.14                 0.08                         2.0
# 2              12.87                 0.44                         3.0
# 3              15.23                 0.44                         2.0
# 5               7.14                 0.19                         2.0
# ...              ...                  ...                         ...
# 44988          11.97                 0.21                         6.0
# 44992          11.01                 0.22                         4.0
# 44993          15.83                 0.14                         5.0
# 44994          10.70                 0.38                         4.0
# 44996          14.07                 0.14                        11.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 0               561                             No            1
# 1               504                            Yes            0
# 2               635                             No            1
# 3               675                             No            1
# 5               532                             No            1
# ...             ...                            ...          ...
# 44988           677                             No            1
# 44992           487                             No            1
# 44993           505                             No            1
# 44994           678                             No            1
# 44996           621                             No            1
#
# [20159 rows x 14 columns]

# %%
female_loan_data["person_education"].value_counts().plot(kind = "bar",color = "brown")
plt.show();

# %%
female_loan_data_1 = female_loan_data[female_loan_data["loan_status"] == 1]

# %%
female_loan_data_1["person_education"].value_counts().plot(kind = "bar",color = "skyblue")
plt.show();

# %%
from scipy.stats import spearmanr

# impact of person employment experience on salarries

spearman_corr,_ = spearmanr(dataset["person_emp_exp"],dataset["person_income"])

print(f"Person_emp_exp_correlation_to_person_income >> {spearman_corr:.3f}")
# Out:
# Person_emp_exp_correlation_to_person_income >> 0.120

# %%
# Graphical representation of the correlation 
dataset["log_of_person_income"] = np.log1p(dataset["person_income"])
dataset["log_of_person_emp_exp"] = np.log1p(dataset["person_emp_exp"])

plt.figure(figsize = (8,6))

sns.regplot(x = dataset["log_of_person_emp_exp"][:20],
            y = dataset["log_of_person_income"][:20], 
            scatter_kws = {"color":"blue"},
            line_kws = {"color":"black"})
plt.grid()
plt.show();

# %%
# Impact of person income on Loan amount

spearmanr_corr_person_income_and_loan_amount, _= spearmanr(dataset["person_income"],dataset["loan_amnt"])
print(f"Correlation Value >> {spearmanr_corr_person_income_and_loan_amount:.3f}")
# Out:
# Correlation Value >> 0.405

# %%
# Graphical view

dataset["log_loan_amount"] = np.log1p(dataset["loan_amnt"])

plt.figure(figsize = (8,6))
sns. regplot(x = dataset["log_of_person_income"][:20],
             y = dataset["log_loan_amount"][:20],
             scatter_kws = {"color":"blue"},
             line_kws = {"color":"black"})
plt.grid()
plt.show();

# %%
spearman_correlation_to_loan_int_rate, P_value = spearmanr(dataset["loan_int_rate"],dataset["loan_amnt"]) 
print(f"Correlation: {spearman_correlation_to_loan_int_rate:.3f}")
print(f"P Value :{P_value:.3f}")
# Out:
# Correlation: 0.105
# P Value :0.000

# %%
# Graphical view

dataset["log_loan_int_rate"] = np.log1p(dataset["loan_int_rate"])

plt.figure(figsize = (8,6))
sns. regplot(x = dataset["log_loan_int_rate"][:20],
             y = dataset["log_loan_amount"][:20],
             scatter_kws = {"color":"blue"},
             line_kws = {"color":"black"})
plt.grid()
plt.show();

# %%
spearman_correlation_to_loan_int_rate, P_value = spearmanr(dataset["cb_person_cred_hist_length"],dataset["loan_amnt"]) 
print(f"Correlation: {spearman_correlation_to_loan_int_rate:.3f}")
print(f"P Value :{P_value:.3f}")
# Out:
# Correlation: 0.043
# P Value :0.000

# %%
# Graphical view

dataset["log_cb_person_cred_hist_length"] = np.log1p(dataset["cb_person_cred_hist_length"])

plt.figure(figsize = (8,6))
sns. regplot(x = dataset["log_cb_person_cred_hist_length"][:20],
             y = dataset["log_loan_amount"][:20],
             scatter_kws = {"color":"blue"},
             line_kws = {"color":"black"})
plt.grid()
plt.show();

# %%
loan_acquired = dataset[dataset["loan_status"] == 1]
no_loan_acquired = dataset[dataset["loan_status"] == 0]

# %%
plt.figure(figsize = (15,6))
loan_acquired[["person_gender","person_education"]].value_counts().plot(kind = "bar",color = "gray")
plt.show();

# %%
plt.figure(figsize = (15,6))
no_loan_acquired[["person_gender","person_education"]].value_counts().plot(kind = "bar",color = "blue")
plt.grid()
plt.show();

# %%
from scipy.stats import ttest_ind

ttest_ind(loan_acquired["person_income"],no_loan_acquired["person_income"])
# Out:
# TtestResult(statistic=-29.077927824499543, pvalue=3.4830994169490465e-184, df=44998.0)

# %%
ttest_ind(loan_acquired["person_emp_exp"],no_loan_acquired["person_emp_exp"])
# Out:
# TtestResult(statistic=-4.345546092915819, pvalue=1.3923370134917003e-05, df=44998.0)

# %%
ttest_ind(loan_acquired["cb_person_cred_hist_length"],no_loan_acquired["cb_person_cred_hist_length"])
# Out:
# TtestResult(statistic=-3.1505831673919937, pvalue=0.00163051562774701, df=44998.0)

# %%
loan_acquired["log_acquired_loan_person_income"] = np.log1p(loan_acquired["person_income"])
no_loan_acquired["log_no_acquired_loan_person_income"]  = np.log1p(no_loan_acquired["person_income"])
# Out:
# C:\Users\Efo Coder\AppData\Local\Temp\ipykernel_11064\597138442.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loan_acquired["log_acquired_loan_person_income"] = np.log1p(loan_acquired["person_income"])
# C:\Users\Efo Coder\AppData\Local\Temp\ipykernel_11064\597138442.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_loan_acquired["log_no_acquired_loan_person_income"]  = np.log1p(no_loan_acquired["person_income"])

# %%
plt.figure(figsize = (8,6))

sns.regplot(x = loan_acquired["log_acquired_loan_person_income"][:500],
            y = no_loan_acquired["log_no_acquired_loan_person_income"][:500],
            scatter_kws = {"color":"blue"},line_kws = {"color":"black"})

plt.grid()
plt.show();

# %%
quantitative_var_acq = loan_acquired.select_dtypes(exclude = "object")
quantitative_var_acquired = quantitative_var_acq.columns[:8]

quantitative_var_no_acq = no_loan_acquired.select_dtypes(exclude = "object")
quantitative_var_no_acquired = quantitative_var_no_acq.columns[:8]

for loan_var,no_loan_var in zip(quantitative_var_acquired,quantitative_var_no_acquired):
    statistic, p_value = ttest_ind(loan_acquired[loan_var],no_loan_acquired[no_loan_var])
    
    print(f"The T_Score, P_Value Statistic for {loan_var} and {no_loan_var} are  : {statistic:.3f} and {p_value:.3f}")
# Out:
# The T_Score, P_Value Statistic for person_age and person_age are  : -4.557 and 0.000
# The T_Score, P_Value Statistic for person_income and person_income are  : -29.078 and 0.000
# The T_Score, P_Value Statistic for person_emp_exp and person_emp_exp are  : -4.346 and 0.000
# The T_Score, P_Value Statistic for loan_amnt and loan_amnt are  : 22.983 and 0.000
# The T_Score, P_Value Statistic for loan_int_rate and loan_int_rate are  : 74.662 and 0.000
# The T_Score, P_Value Statistic for loan_percent_income and loan_percent_income are  : 88.458 and 0.000
# The T_Score, P_Value Statistic for cb_person_cred_hist_length and cb_person_cred_hist_length are  : -3.151 and 0.002
# The T_Score, P_Value Statistic for credit_score and credit_score are  : -1.622 and 0.105

# %%
loan_acquired
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# 5            21.0        female      High School        12951.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# 2                   3              MORTGAGE     5500.0            MEDICAL
# 3                   0                  RENT    35000.0            MEDICAL
# 4                   1                  RENT    35000.0            MEDICAL
# 5                   0                   OWN     2500.0            VENTURE
# ...               ...                   ...        ...                ...
# 44995               6                  RENT    15000.0            MEDICAL
# 44996              17                  RENT     9000.0    HOMEIMPROVEMENT
# 44997               7                  RENT     2771.0  DEBTCONSOLIDATION
# 44998               4                  RENT    12000.0          EDUCATION
# 44999               1                  RENT     6665.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0              16.02                 0.49                         3.0
# 2              12.87                 0.44                         3.0
# 3              15.23                 0.44                         2.0
# 4              14.27                 0.53                         4.0
# 5               7.14                 0.19                         2.0
# ...              ...                  ...                         ...
# 44995          15.66                 0.31                         3.0
# 44996          14.07                 0.14                        11.0
# 44997          10.02                 0.05                        10.0
# 44998          13.23                 0.36                         6.0
# 44999          17.05                 0.13                         3.0
#
#        credit_score previous_loan_defaults_on_file  loan_status  \
# 0               561                             No            1
# 2               635                             No            1
# 3               675                             No            1
# 4               586                             No            1
# 5               532                             No            1
# ...             ...                            ...          ...
# 44995           645                             No            1
# 44996           621                             No            1
# 44997           668                             No            1
# 44998           604                             No            1
# 44999           628                             No            1
#
#        log_of_person_income  log_of_person_emp_exp  log_loan_amount  \
# 0                 11.183713               0.000000        10.463132
# 2                  9.428592               1.386294         8.612685
# 3                 11.286702               0.000000        10.463132
# 4                 11.099469               0.693147        10.463132
# 5                  9.469005               0.000000         7.824446
# ...                     ...                    ...              ...
# 44995             10.778373               1.945910         9.615872
# 44996             11.094390               2.890372         9.105091
# 44997             10.949806               2.079442         7.927324
# 44998             10.409250               1.609438         9.392745
# 44999             10.851471               0.693147         8.804775
#
#        log_loan_int_rate  log_cb_person_cred_hist_length  \
# 0               2.834389                        1.386294
# 2               2.629728                        1.386294
# 3               2.786861                        1.098612
# 4               2.725890                        1.609438
# 5               2.096790                        1.098612
# ...                  ...                             ...
# 44995           2.813011                        1.386294
# 44996           2.712706                        2.484907
# 44997           2.399712                        2.397895
# 44998           2.655352                        1.945910
# 44999           2.893146                        1.386294
#
#        log_acquired_loan_person_income
# 0                            11.183713
# 2                             9.428592
# 3                            11.286702
# 4                            11.099469
# 5                             9.469005
# ...                                ...
# 44995                        10.778373
# 44996                        11.094390
# 44997                        10.949806
# 44998                        10.409250
# 44999                        10.851471
#
# [10000 rows x 20 columns]

# %%
no_loan_acquired
# Out:
#        person_age person_gender person_education  person_income  \
# 1            21.0        female      High School        12282.0
# 14           23.0        female        Associate       138998.0
# 15           23.0        female           Master       600891.0
# 16           23.0          male         Bachelor       144943.0
# 20           25.0          male         Bachelor       195718.0
# ...           ...           ...              ...            ...
# 42103        36.0          male         Bachelor        60006.0
# 42104        25.0        female         Bachelor        64146.0
# 42105        43.0          male        Doctorate        93061.0
# 42106        28.0        female      High School       110291.0
# 42107        26.0        female         Bachelor        66849.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 1                   0                   OWN     1000.0          EDUCATION
# 14                  0                  RENT    35000.0          EDUCATION
# 15                  5              MORTGAGE    30000.0  DEBTCONSOLIDATION
# 16                  0                  RENT    35000.0          EDUCATION
# 20                  0                  RENT    35000.0            VENTURE
# ...               ...                   ...        ...                ...
# 42103              15                   OWN     2755.0            MEDICAL
# 42104               2              MORTGAGE     7200.0            VENTURE
# 42105              21              MORTGAGE    12966.0            VENTURE
# 42106               7                  RENT    13453.0            VENTURE
# 42107               1                  RENT     4000.0           PERSONAL
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 1              11.14                 0.08                         2.0
# 14              7.90                 0.25                         4.0
# 15             10.65                 0.05                         3.0
# 16              7.90                 0.24                         4.0
# 20              7.49                 0.18                         4.0
# ...              ...                  ...                         ...
# 42103           8.92                 0.05                         9.0
# 42104          10.28                 0.11                         3.0
# 42105          14.40                 0.14                        12.0
# 42106          13.29                 0.12                         6.0
# 42107          10.99                 0.06                         4.0
#
#        credit_score previous_loan_defaults_on_file  loan_status  \
# 1               504                            Yes            0
# 14              583                             No            0
# 15              670                            Yes            0
# 16              663                             No            0
# 20              684                            Yes            0
# ...             ...                            ...          ...
# 42103           609                            Yes            0
# 42104           625                            Yes            0
# 42105           690                            Yes            0
# 42106           631                            Yes            0
# 42107           550                            Yes            0
#
#        log_of_person_income  log_of_person_emp_exp  log_loan_amount  \
# 1                  9.415971               0.000000         6.908755
# 14                11.842222               0.000000        10.463132
# 15                13.306170               1.791759        10.308986
# 16                11.884103               0.000000        10.463132
# 20                12.184435               0.000000        10.463132
# ...                     ...                    ...              ...
# 42103             11.002217               2.772589         7.921536
# 42104             11.068933               1.098612         8.881975
# 42105             11.441021               3.091042         9.470163
# 42106             11.610887               2.079442         9.507032
# 42107             11.110207               0.693147         8.294300
#
#        log_loan_int_rate  log_cb_person_cred_hist_length  \
# 1               2.496506                        1.098612
# 14              2.186051                        1.609438
# 15              2.455306                        1.386294
# 16              2.186051                        1.609438
# 20              2.138889                        1.609438
# ...                  ...                             ...
# 42103           2.294553                        2.302585
# 42104           2.423031                        1.386294
# 42105           2.734368                        2.564949
# 42106           2.659560                        1.945910
# 42107           2.484073                        1.609438
#
#        log_no_acquired_loan_person_income
# 1                                9.415971
# 14                              11.842222
# 15                              13.306170
# 16                              11.884103
# 20                              12.184435
# ...                                   ...
# 42103                           11.002217
# 42104                           11.068933
# 42105                           11.441021
# 42106                           11.610887
# 42107                           11.110207
#
# [35000 rows x 20 columns]
